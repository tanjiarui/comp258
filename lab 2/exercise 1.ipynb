# %%
import numpy as np, json
from sklearn import preprocessing
from sklearn.metrics import classification_report

sigmoid = lambda x: 1 / (1 + np.exp(-x))
def backprop(W1, W2, X, Y, alpha=.2):
	for b in range(X.shape[0]):
		x = X[b, :].T  # inputs from training data
		y = Y[b]  # correct output from training data
		##########################
		# forward propagation step
		##########################
		# calculate the weighted sum of hidden node
		v1 = np.dot(W1, x)
		# pass the weighted sum to the activation function, this gives the outputs from hidden layer
		y1 = sigmoid(v1)
		# calculate the weighted sum of the output layer
		v = np.dot(W2, y1)
		# pass it to the activation function, this returns the output of the third layer
		y_hat = sigmoid(v)
		# calculate the error, difference between correct output and computed output
		error = y - y_hat
		# calculate delta, derivative of the activation function times the error
		# note that 𝜎′(𝑥)=𝜎(𝑥)∙(1− 𝜎(𝑥)) = y * (1-y)
		delta = y_hat * (1 - y_hat) * error  # element wise multiplication
		###########################
		# Backward propagation step
		# Stochastic Gradient Descent
		###########################
		# propagate the output node delta, δ, backward, and calculate the deltas of the hidden layer.
		e1 = np.dot(W2.T, delta)
		delta1 = y1 * (1 - y1) * e1  # element wise multiplication

		# Adjust the weights according to the learning rule
		delta1 = delta1.reshape(delta1.size, 1)
		x = x.reshape(1, x.size)
		dW1 = alpha * np.dot(delta1, x)
		W1 = W1 + dW1
		delta = delta.reshape(delta.size, 1)
		y1 = y1.reshape(1, y1.size)
		dW2 = alpha * np.dot(delta, y1)
		W2 = W2 + dW2

	return W1, W2

def train(X, y, node, lr=.2, epoch=10000):
	input_size, output_size = X.shape[1], np.unique(y).size
	# initialize the weights between input layer and hidden layer
	W1 = 2 * np.random.rand(node, input_size) - 1
	# initialize the weights between hidden layer and output layer
	W2 = 2 * np.random.rand(output_size, node) - 1
	for e in range(epoch): # train
		W1, W2 = backprop(W1, W2, X, y, lr)
	return W1, W2

def predict(X, W1, W2):
	y = []
	for b in range(X.shape[0]):
		x = X[b, :].T
		# calculate the weighted sum of hidden node
		v1 = np.dot(W1, x)
		# pass the weighted sum to the activation function, this gives the outputs from hidden layer
		y1 = sigmoid(v1)
		# calculate the weighted sum of the output layer
		v = np.dot(W2, y1)
		# pass it to the activation function, this returns the output of the third layer
		y.append(np.argmax(sigmoid(v)))
	return y

with open('iris.json', 'r', encoding='utf-8-sig') as file:
	iris = json.load(file)
for index in range(len(iris)):
	iris[index] = list(iris[index].values())
iris = np.array(iris)
X, y = iris[:, :4].astype('float'), iris[:, 4]
y = preprocessing.LabelEncoder().fit_transform(y)
for alpha in np.arange(0, .5, .02):
	w1, w2 = train(X, y, 5, alpha)
	prediction = predict(X, w1, w2)
	print('learning rate: ' + str(alpha))
	print(classification_report(y, prediction))
# Out:
# learning rate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50        49
#            1       0.00      0.00      0.00        49
#            2       0.00      0.00      0.00        49
#
#     accuracy                           0.33       147
#    macro avg       0.11      0.33      0.17       147
# weighted avg       0.11      0.33      0.17       147
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# learning rate: 0.02
#               precision    recall  f1-score   support
#
#            0       0.02      0.02      0.02        49
#            1       0.24      0.24      0.24        49
#            2       0.47      0.53      0.50        49
#
#     accuracy                           0.27       147
#    macro avg       0.24      0.27      0.25       147
# weighted avg       0.24      0.27      0.25       147
#
# learning rate: 0.04
#               precision    recall  f1-score   support
#
#            0       0.52      0.96      0.67        49
#            1       0.00      0.00      0.00        49
#            2       0.88      1.00      0.93        49
#
#     accuracy                           0.65       147
#    macro avg       0.46      0.65      0.53       147
# weighted avg       0.46      0.65      0.53       147
#
# learning rate: 0.06
#               precision    recall  f1-score   support
#
#            0       0.48      0.65      0.55        49
#            1       0.00      0.00      0.00        49
#            2       0.40      0.35      0.37        49
#
#     accuracy                           0.33       147
#    macro avg       0.29      0.33      0.31       147
# weighted avg       0.29      0.33      0.31       147
#
# learning rate: 0.08
#               precision    recall  f1-score   support
#
#            0       0.22      0.27      0.24        49
#            1       0.55      0.84      0.66        49
#            2       0.58      0.14      0.23        49
#
#     accuracy                           0.41       147
#    macro avg       0.45      0.41      0.38       147
# weighted avg       0.45      0.41      0.38       147
#
# learning rate: 0.1
#               precision    recall  f1-score   support
#
#            0       0.11      0.12      0.12        49
#            1       0.33      0.02      0.04        49
#            2       0.04      0.08      0.06        49
#
#     accuracy                           0.07       147
#    macro avg       0.16      0.07      0.07       147
# weighted avg       0.16      0.07      0.07       147
#
# learning rate: 0.12
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        49
#            1       0.16      0.18      0.17        49
#            2       0.55      1.00      0.71        49
#
#     accuracy                           0.39       147
#    macro avg       0.24      0.39      0.29       147
# weighted avg       0.24      0.39      0.29       147
#
# learning rate: 0.14
#               precision    recall  f1-score   support
#
#            0       0.53      0.94      0.68        49
#            1       0.81      0.35      0.49        49
#            2       0.87      0.69      0.77        49
#
#     accuracy                           0.66       147
#    macro avg       0.74      0.66      0.64       147
# weighted avg       0.74      0.66      0.64       147
#
# learning rate: 0.16
#               precision    recall  f1-score   support
#
#            0       1.00      0.35      0.52        49
#            1       0.77      0.73      0.75        49
#            2       0.58      0.98      0.73        49
#
#     accuracy                           0.69       147
#    macro avg       0.78      0.69      0.66       147
# weighted avg       0.78      0.69      0.66       147
#
# learning rate: 0.18
#               precision    recall  f1-score   support
#
#            0       0.76      0.39      0.51        49
#            1       0.00      0.00      0.00        49
#            2       0.08      0.12      0.10        49
#
#     accuracy                           0.17       147
#    macro avg       0.28      0.17      0.20       147
# weighted avg       0.28      0.17      0.20       147
#
# learning rate: 0.2
#               precision    recall  f1-score   support
#
#            0       0.12      0.14      0.13        49
#            1       0.10      0.06      0.08        49
#            2       0.02      0.02      0.02        49
#
#     accuracy                           0.07       147
#    macro avg       0.08      0.07      0.08       147
# weighted avg       0.08      0.07      0.08       147
#
# learning rate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.66      0.55      0.60        49
#            1       0.32      0.51      0.39        49
#            2       0.04      0.02      0.03        49
#
#     accuracy                           0.36       147
#    macro avg       0.34      0.36      0.34       147
# weighted avg       0.34      0.36      0.34       147
#
# learning rate: 0.24
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.70        49
#            1       0.08      0.08      0.08        49
#            2       0.00      0.00      0.00        49
#
#     accuracy                           0.36       147
#    macro avg       0.20      0.36      0.26       147
# weighted avg       0.20      0.36      0.26       147
#
# learning rate: 0.26
#               precision    recall  f1-score   support
#
#            0       0.18      0.14      0.16        49
#            1       0.39      0.43      0.41        49
#            2       0.00      0.00      0.00        49
#
#     accuracy                           0.19       147
#    macro avg       0.19      0.19      0.19       147
# weighted avg       0.19      0.19      0.19       147
#
# learning rate: 0.28
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        49
#            1       0.43      0.92      0.59        49
#            2       0.62      0.10      0.18        49
#
#     accuracy                           0.34       147
#    macro avg       0.35      0.34      0.25       147
# weighted avg       0.35      0.34      0.25       147
#
# learning rate: 0.3
#               precision    recall  f1-score   support
#
#            0       0.17      0.24      0.20        49
#            1       0.37      0.53      0.43        49
#            2       0.00      0.00      0.00        49
#
#     accuracy                           0.26       147
#    macro avg       0.18      0.26      0.21       147
# weighted avg       0.18      0.26      0.21       147
#
# learning rate: 0.32
#               precision    recall  f1-score   support
#
#            0       0.03      0.02      0.03        49
#            1       0.41      0.92      0.57        49
#            2       0.33      0.04      0.07        49
#
#     accuracy                           0.33       147
#    macro avg       0.26      0.33      0.22       147
# weighted avg       0.26      0.33      0.22       147
#
# learning rate: 0.34
#               precision    recall  f1-score   support
#
#            0       0.21      0.29      0.24        49
#            1       0.67      0.49      0.56        49
#            2       0.11      0.10      0.11        49
#
#     accuracy                           0.29       147
#    macro avg       0.33      0.29      0.30       147
# weighted avg       0.33      0.29      0.30       147
#
# learning rate: 0.36
#               precision    recall  f1-score   support
#
#            0       0.12      0.04      0.06        49
#            1       0.39      0.76      0.51        49
#            2       0.89      0.65      0.75        49
#
#     accuracy                           0.48       147
#    macro avg       0.47      0.48      0.44       147
# weighted avg       0.47      0.48      0.44       147
#
# learning rate: 0.38
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        49
#            1       0.00      0.00      0.00        49
#            2       0.06      0.12      0.08        49
#
#     accuracy                           0.04       147
#    macro avg       0.02      0.04      0.03       147
# weighted avg       0.02      0.04      0.03       147
#
# learning rate: 0.4
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        49
#            1       0.62      0.84      0.71        49
#            2       0.26      0.24      0.25        49
#
#     accuracy                           0.36       147
#    macro avg       0.29      0.36      0.32       147
# weighted avg       0.29      0.36      0.32       147
#
# learning rate: 0.42
#               precision    recall  f1-score   support
#
#            0       0.47      0.86      0.60        49
#            1       0.04      0.04      0.04        49
#            2       0.75      0.06      0.11        49
#
#     accuracy                           0.32       147
#    macro avg       0.42      0.32      0.25       147
# weighted avg       0.42      0.32      0.25       147
#
# learning rate: 0.44
#               precision    recall  f1-score   support
#
#            0       0.13      0.08      0.10        49
#            1       0.53      0.98      0.69        49
#            2       0.65      0.35      0.45        49
#
#     accuracy                           0.47       147
#    macro avg       0.44      0.47      0.41       147
# weighted avg       0.44      0.47      0.41       147
#
# learning rate: 0.46
#               precision    recall  f1-score   support
#
#            0       0.12      0.02      0.04        49
#            1       0.02      0.02      0.02        49
#            2       0.06      0.12      0.08        49
#
#     accuracy                           0.05       147
#    macro avg       0.07      0.05      0.05       147
# weighted avg       0.07      0.05      0.05       147
#
# learning rate: 0.48
#               precision    recall  f1-score   support
#
#            0       0.33      0.41      0.36        49
#            1       0.11      0.02      0.03        49
#            2       0.10      0.16      0.13        49
#
#     accuracy                           0.20       147
#    macro avg       0.18      0.20      0.18       147
# weighted avg       0.18      0.20      0.18       147
